# %%
import pandas as pd

# %%
df = pd.read_csv('/Users/shivakumargoudmucharla/Downloads/creditcard.csv')

# %%
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
#         V26       V27       V28  Amount  Class
# 0 -0.189115  0.133558 -0.021053  149.62      0
# 1  0.125895 -0.008983  0.014724    2.69      0
# 2 -0.139097 -0.055353 -0.059752  378.66      0
# 3 -0.221929  0.062723  0.061458  123.50      0
# 4  0.502292  0.219422  0.215153   69.99      0
#
# [5 rows x 31 columns]

# %%
pd.options.display.max_columns = None

# %%
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9       V10       V11       V12       V13       V14  \
# 0  0.098698  0.363787  0.090794 -0.551600 -0.617801 -0.991390 -0.311169
# 1  0.085102 -0.255425 -0.166974  1.612727  1.065235  0.489095 -0.143772
# 2  0.247676 -1.514654  0.207643  0.624501  0.066084  0.717293 -0.165946
# 3  0.377436 -1.387024 -0.054952 -0.226487  0.178228  0.507757 -0.287924
# 4 -0.270533  0.817739  0.753074 -0.822843  0.538196  1.345852 -1.119670
#
#         V15       V16       V17       V18       V19       V20       V21  \
# 0  1.468177 -0.470401  0.207971  0.025791  0.403993  0.251412 -0.018307
# 1  0.635558  0.463917 -0.114805 -0.183361 -0.145783 -0.069083 -0.225775
# 2  2.345865 -2.890083  1.109969 -0.121359 -2.261857  0.524980  0.247998
# 3 -0.631418 -1.059647 -0.684093  1.965775 -1.232622 -0.208038 -0.108300
# 4  0.175121 -0.451449 -0.237033 -0.038195  0.803487  0.408542 -0.009431
#
#         V22       V23       V24       V25       V26       V27       V28  \
# 0  0.277838 -0.110474  0.066928  0.128539 -0.189115  0.133558 -0.021053
# 1 -0.638672  0.101288 -0.339846  0.167170  0.125895 -0.008983  0.014724
# 2  0.771679  0.909412 -0.689281 -0.327642 -0.139097 -0.055353 -0.059752
# 3  0.005274 -0.190321 -1.175575  0.647376 -0.221929  0.062723  0.061458
# 4  0.798278 -0.137458  0.141267 -0.206010  0.502292  0.219422  0.215153
#
#    Amount  Class
# 0  149.62      0
# 1    2.69      0
# 2  378.66      0
# 3  123.50      0
# 4   69.99      0

# %%
df.shape
# Out:
# (284807, 31)

# %%
df.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
from sklearn.preprocessing import StandardScaler

# %%
sc = StandardScaler()
df['Amount'] = sc.fit_transform(pd.DataFrame(df['Amount']))

# %%
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9       V10       V11       V12       V13       V14  \
# 0  0.098698  0.363787  0.090794 -0.551600 -0.617801 -0.991390 -0.311169
# 1  0.085102 -0.255425 -0.166974  1.612727  1.065235  0.489095 -0.143772
# 2  0.247676 -1.514654  0.207643  0.624501  0.066084  0.717293 -0.165946
# 3  0.377436 -1.387024 -0.054952 -0.226487  0.178228  0.507757 -0.287924
# 4 -0.270533  0.817739  0.753074 -0.822843  0.538196  1.345852 -1.119670
#
#         V15       V16       V17       V18       V19       V20       V21  \
# 0  1.468177 -0.470401  0.207971  0.025791  0.403993  0.251412 -0.018307
# 1  0.635558  0.463917 -0.114805 -0.183361 -0.145783 -0.069083 -0.225775
# 2  2.345865 -2.890083  1.109969 -0.121359 -2.261857  0.524980  0.247998
# 3 -0.631418 -1.059647 -0.684093  1.965775 -1.232622 -0.208038 -0.108300
# 4  0.175121 -0.451449 -0.237033 -0.038195  0.803487  0.408542 -0.009431
#
#         V22       V23       V24       V25       V26       V27       V28  \
# 0  0.277838 -0.110474  0.066928  0.128539 -0.189115  0.133558 -0.021053
# 1 -0.638672  0.101288 -0.339846  0.167170  0.125895 -0.008983  0.014724
# 2  0.771679  0.909412 -0.689281 -0.327642 -0.139097 -0.055353 -0.059752
# 3  0.005274 -0.190321 -1.175575  0.647376 -0.221929  0.062723  0.061458
# 4  0.798278 -0.137458  0.141267 -0.206010  0.502292  0.219422  0.215153
#
#      Amount  Class
# 0  0.244964      0
# 1 -0.342475      0
# 2  1.160686      0
# 3  0.140534      0
# 4 -0.073403      0

# %%
df = df.drop(['Time'],axis = 1)

# %%
df
# Out:
#                V1         V2        V3        V4        V5        V6  \
# 0       -1.359807  -0.072781  2.536347  1.378155 -0.338321  0.462388
# 1        1.191857   0.266151  0.166480  0.448154  0.060018 -0.082361
# 2       -1.358354  -1.340163  1.773209  0.379780 -0.503198  1.800499
# 3       -0.966272  -0.185226  1.792993 -0.863291 -0.010309  1.247203
# 4       -1.158233   0.877737  1.548718  0.403034 -0.407193  0.095921
# ...           ...        ...       ...       ...       ...       ...
# 284802 -11.881118  10.071785 -9.834783 -2.066656 -5.364473 -2.606837
# 284803  -0.732789  -0.055080  2.035030 -0.738589  0.868229  1.058415
# 284804   1.919565  -0.301254 -3.249640 -0.557828  2.630515  3.031260
# 284805  -0.240440   0.530483  0.702510  0.689799 -0.377961  0.623708
# 284806  -0.533413  -0.189733  0.703337 -0.506271 -0.012546 -0.649617
#
#               V7        V8        V9       V10       V11       V12       V13  \
# 0       0.239599  0.098698  0.363787  0.090794 -0.551600 -0.617801 -0.991390
# 1      -0.078803  0.085102 -0.255425 -0.166974  1.612727  1.065235  0.489095
# 2       0.791461  0.247676 -1.514654  0.207643  0.624501  0.066084  0.717293
# 3       0.237609  0.377436 -1.387024 -0.054952 -0.226487  0.178228  0.507757
# 4       0.592941 -0.270533  0.817739  0.753074 -0.822843  0.538196  1.345852
# ...          ...       ...       ...       ...       ...       ...       ...
# 284802 -4.918215  7.305334  1.914428  4.356170 -1.593105  2.711941 -0.689256
# 284803  0.024330  0.294869  0.584800 -0.975926 -0.150189  0.915802  1.214756
# 284804 -0.296827  0.708417  0.432454 -0.484782  0.411614  0.063119 -0.183699
# 284805 -0.686180  0.679145  0.392087 -0.399126 -1.933849 -0.962886 -1.042082
# 284806  1.577006 -0.414650  0.486180 -0.915427 -1.040458 -0.031513 -0.188093
#
#              V14       V15       V16       V17       V18       V19       V20  \
# 0      -0.311169  1.468177 -0.470401  0.207971  0.025791  0.403993  0.251412
# 1      -0.143772  0.635558  0.463917 -0.114805 -0.183361 -0.145783 -0.069083
# 2      -0.165946  2.345865 -2.890083  1.109969 -0.121359 -2.261857  0.524980
# 3      -0.287924 -0.631418 -1.059647 -0.684093  1.965775 -1.232622 -0.208038
# 4      -1.119670  0.175121 -0.451449 -0.237033 -0.038195  0.803487  0.408542
# ...          ...       ...       ...       ...       ...       ...       ...
# 284802  4.626942 -0.924459  1.107641  1.991691  0.510632 -0.682920  1.475829
# 284803 -0.675143  1.164931 -0.711757 -0.025693 -1.221179 -1.545556  0.059616
# 284804 -0.510602  1.329284  0.140716  0.313502  0.395652 -0.577252  0.001396
# 284805  0.449624  1.962563 -0.608577  0.509928  1.113981  2.897849  0.127434
# 284806 -0.084316  0.041333 -0.302620 -0.660377  0.167430 -0.256117  0.382948
#
#              V21       V22       V23       V24       V25       V26       V27  \
# 0      -0.018307  0.277838 -0.110474  0.066928  0.128539 -0.189115  0.133558
# 1      -0.225775 -0.638672  0.101288 -0.339846  0.167170  0.125895 -0.008983
# 2       0.247998  0.771679  0.909412 -0.689281 -0.327642 -0.139097 -0.055353
# 3      -0.108300  0.005274 -0.190321 -1.175575  0.647376 -0.221929  0.062723
# 4      -0.009431  0.798278 -0.137458  0.141267 -0.206010  0.502292  0.219422
# ...          ...       ...       ...       ...       ...       ...       ...
# 284802  0.213454  0.111864  1.014480 -0.509348  1.436807  0.250034  0.943651
# 284803  0.214205  0.924384  0.012463 -1.016226 -0.606624 -0.395255  0.068472
# 284804  0.232045  0.578229 -0.037501  0.640134  0.265745 -0.087371  0.004455
# 284805  0.265245  0.800049 -0.163298  0.123205 -0.569159  0.546668  0.108821
# 284806  0.261057  0.643078  0.376777  0.008797 -0.473649 -0.818267 -0.002415
#
#              V28    Amount  Class
# 0      -0.021053  0.244964      0
# 1       0.014724 -0.342475      0
# 2      -0.059752  1.160686      0
# 3       0.061458  0.140534      0
# 4       0.215153 -0.073403      0
# ...          ...       ...    ...
# 284802  0.823731 -0.350151      0
# 284803 -0.053527 -0.254117      0
# 284804 -0.026561 -0.081839      0
# 284805  0.104533 -0.313249      0
# 284806  0.013649  0.514355      0
#
# [284807 rows x 30 columns]

# %%
df.duplicated().any()
# Out:
# True

# %%
df.duplicated().sum()
# Out:
# 9144

# %%
df = df.drop_duplicates()

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.shape
# Out:
# (275663, 30)

# %%
df['Class'].value_counts()
# Out:
# 0    275190
# 1       473
# Name: Class, dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Apply the ggplot style for the plot
plt.style.use('ggplot')


sns.countplot(x='Class', data=df)

# Add title and labels
plt.title('Count of Classes')
plt.xlabel('Class')
plt.ylabel('Count')

# Show the plot
plt.show()

# %%
x = df.drop('Class',axis = 1)
y = df['Class']

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test,y_train, y_test = train_test_split(x,y, test_size = 0.2, random_state = 42)

# %%
import numpy as np

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score

# %%
classifier = { 
"LogisticRegression":  LogisticRegression(),
"Decision Tree Classifier": DecisionTreeClassifier()}

for name, clf in classifier.items():
    print(f"\n----------{name}-----------")
    clf.fit(x_train,y_train)
    y_pred = clf.predict(x_test)
    print(f"\n Accuracy: {accuracy_score(y_pred,y_test)}")
    print(f"\n Precision: {precision_score(y_pred,y_test)}")
    print(f"\n Recall: {recall_score(y_pred,y_test)}")
    print(f"\n F1score: {f1_score(y_pred,y_test)}")
# Out:
# ----------LogisticRegression-----------
#
#  Accuracy: 0.9992200678359603
#
#  Precision: 0.6043956043956044
#
#  Recall: 0.8870967741935484
#
#  F1score: 0.718954248366013
#
# ----------Decision Tree Classifier-----------
#
#  Accuracy: 0.9989298605191084
#
#  Precision: 0.7362637362637363
#
#  Recall: 0.6568627450980392
#
#  F1score: 0.6943005181347152

# %%
# undersampling

normal = df[df['Class']==0]
fraud = df[df['Class']==1 ]

# %%
normal.shape
# Out:
# (275190, 30)

# %%
fraud.shape
# Out:
# (473, 30)

# %%
normal_sample = normal.sample(n=473)

# %%
normal_sample.shape
# Out:
# (473, 30)

# %%
df1 = pd.concat([normal_sample,fraud],ignore_index = True)

# %%
df1
# Out:
#            V1        V2        V3        V4        V5        V6        V7  \
# 0    0.153652  0.964638 -1.276917 -0.197422  0.415095 -0.864980  0.469466
# 1    1.960366 -0.172455 -3.102099  0.279389  2.905309  3.312628  0.049175
# 2    0.274847 -0.824451  1.282605 -0.817824 -1.624529 -0.556323 -0.771134
# 3   -1.046058  1.143298  1.382229 -0.118098 -0.135796 -0.315636  0.153510
# 4   -0.859408  0.362259 -0.257749 -1.806948  0.819693  3.853970 -1.723923
# ..        ...       ...       ...       ...       ...       ...       ...
# 941 -1.927883  1.125653 -4.518331  1.749293 -1.566487 -2.010494 -0.882850
# 942  1.378559  1.289381 -5.004247  1.411850  0.442581 -1.326536 -1.413170
# 943 -0.676143  1.126366 -2.213700  0.468308 -1.120541 -0.003346 -2.234739
# 944 -3.113832  0.585864 -5.399730  1.817092 -0.840618 -2.943548 -2.208002
# 945  1.991976  0.158476 -2.583441  0.408670  1.151147 -0.096695  0.223050
#
#            V8        V9       V10       V11       V12       V13       V14  \
# 0    0.344008 -0.211155 -0.977828  0.437886 -0.218376 -1.208356 -0.209203
# 1    0.664734  0.041266  0.266835 -0.254349  0.327154 -0.398425  0.729832
# 2   -0.094116 -2.130026  1.582838 -0.666069 -1.364208  0.444432 -0.390915
# 3    0.645157 -0.879871 -0.438492  1.520203  0.878296 -0.162018  0.740519
# 4    1.861512 -1.181257 -0.065514 -0.873472 -0.588882  0.214509 -0.043873
# ..        ...       ...       ...       ...       ...       ...       ...
# 941  0.697211 -2.064945 -5.587794  2.115795 -5.417424 -1.235123 -6.665177
# 942  0.248525 -1.127396 -3.232153  2.858466 -3.096915 -0.792532 -5.210141
# 943  1.210158 -0.652250 -3.463891  1.794969 -2.775022 -0.418950 -4.057162
# 944  1.058733 -1.632333 -5.245984  1.933520 -5.030465 -1.127455 -6.416628
# 945 -0.068384  0.577829 -0.888722  0.491140  0.728903  0.380428 -1.948883
#
#           V15       V16       V17       V18       V19       V20       V21  \
# 0    0.128462  0.637757  0.313124  1.567624  0.205057 -0.246215  0.341128
# 1   -0.143575 -0.748924 -0.269695 -0.687767 -0.286775 -0.148448  0.062084
# 2    1.408818 -0.861570  0.923012  0.759425  1.227697  0.061027  0.191701
# 3    0.358270  0.143812 -0.104478 -0.304479 -0.097464 -0.008558 -0.073411
# 4    0.030984  1.021005  0.617912 -0.465629  1.851182  0.074990  0.425876
# ..        ...       ...       ...       ...       ...       ...       ...
# 941  0.401701 -2.897825 -4.570529 -1.315147  0.391167  1.252967  0.778584
# 942 -0.613803 -2.155297 -3.267116 -0.688505  0.737657  0.226138  0.370612
# 943 -0.712616 -1.603015 -5.035326 -0.507000  0.266272  0.247968  0.751826
# 944  0.141237 -2.549498 -4.614717 -1.478138 -0.035480  0.306271  0.583276
# 945 -0.832498  0.519436  0.903562  1.197315  0.593509 -0.017652 -0.164350
#
#           V22       V23       V24       V25       V26       V27       V28  \
# 0    0.854419 -0.098866 -0.607505 -0.268708 -0.136388 -0.087322 -0.060512
# 1    0.207766  0.001423  0.709076  0.498671 -0.475326 -0.004794 -0.062262
# 2    0.887575  0.369541  0.382207 -1.436363 -0.092382  0.306646  0.272015
# 3   -0.323091  0.046429  0.204985 -0.352365  0.070369  0.197808  0.086092
# 4    0.922954 -0.201620  1.071148  0.035853  0.032265 -0.207169  0.007274
# ..        ...       ...       ...       ...       ...       ...       ...
# 941 -0.319189  0.639419 -0.294885  0.537503  0.788395  0.292680  0.147968
# 942  0.028234 -0.145640 -0.081049  0.521875  0.739467  0.389152  0.186637
# 943  0.834108  0.190944  0.032070 -0.739695  0.471111  0.385107  0.194361
# 944 -0.269209 -0.456108 -0.183659 -0.328168  0.606116  0.884876 -0.253700
# 945 -0.295135 -0.072173 -0.450261  0.313267 -0.289617  0.002988 -0.015309
#
#        Amount  Class
# 0   -0.227450      0
# 1   -0.186509      0
# 2   -0.037381      0
# 3   -0.347232      0
# 4   -0.349231      0
# ..        ...    ...
# 941  1.206024      1
# 942 -0.350191      1
# 943 -0.041818      1
# 944  0.626302      1
# 945 -0.183191      1
#
# [946 rows x 30 columns]

# %%
df1.shape
# Out:
# (946, 30)

# %%
df1['Class'].value_counts()
# Out:
# 0    473
# 1    473
# Name: Class, dtype: int64

# %%
x = df1.drop('Class',axis = 1)
y = df1['Class']

# %%
x_train, x_test,y_train, y_test = train_test_split(x,y, test_size = 0.2, random_state = 42)

# %%
classifier = { 
"LogisticRegression":  LogisticRegression(),
"Decision Tree Classifier": DecisionTreeClassifier()}

for name, clf in classifier.items():
    print(f"\n----------{name}-----------")
    clf.fit(x_train,y_train)
    y_pred = clf.predict(x_test)
    print(f"\n Accuracy: {accuracy_score(y_pred,y_test)}")
    print(f"\n Precision: {precision_score(y_pred,y_test)}")
    print(f"\n Recall: {recall_score(y_pred,y_test)}")
    print(f"\n F1score: {f1_score(y_pred,y_test)}")
# Out:
# ----------LogisticRegression-----------
#
#  Accuracy: 0.9421052631578948
#
#  Precision: 0.9019607843137255
#
#  Recall: 0.989247311827957
#
#  F1score: 0.9435897435897437
#
# ----------Decision Tree Classifier-----------
#
#  Accuracy: 0.9105263157894737
#
#  Precision: 0.9117647058823529
#
#  Recall: 0.9207920792079208
#
#  F1score: 0.9162561576354681

# %%
#oversampling

x = df.drop('Class',axis = 1)
y = df['Class']

# %%
x.shape
# Out:
# (275663, 29)

# %%
y.shape
# Out:
# (275663,)

# %%
pip install --upgrade scikit-learn imbalanced-learn
# Out:
# Requirement already satisfied: scikit-learn in ./anaconda3/lib/python3.11/site-packages (1.1.3)
# Collecting scikit-learn
#   Obtaining dependency information for scikit-learn from https://files.pythonhosted.org/packages/cd/7a/19fe32c810c5ceddafcfda16276d98df299c8649e24e84d4f00df4a91e01/scikit_learn-1.5.2-cp311-cp311-macosx_12_0_arm64.whl.metadata
#   Using cached scikit_learn-1.5.2-cp311-cp311-macosx_12_0_arm64.whl.metadata (13 kB)
# Requirement already satisfied: imbalanced-learn in ./anaconda3/lib/python3.11/site-packages (0.9.1)
# Collecting imbalanced-learn
#   Obtaining dependency information for imbalanced-learn from https://files.pythonhosted.org/packages/5a/fa/267de06c95210580f4b82b45cec1ce1e9ce1f21a01a684367db89e7da70d/imbalanced_learn-0.12.3-py3-none-any.whl.metadata
#   Using cached imbalanced_learn-0.12.3-py3-none-any.whl.metadata (8.3 kB)
# Requirement already satisfied: numpy>=1.19.5 in ./anaconda3/lib/python3.11/site-packages (from scikit-learn) (1.24.3)
# Requirement already satisfied: scipy>=1.6.0 in ./anaconda3/lib/python3.11/site-packages (from scikit-learn) (1.10.1)
# Requirement already satisfied: joblib>=1.2.0 in ./anaconda3/lib/python3.11/site-packages (from scikit-learn) (1.2.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in ./anaconda3/lib/python3.11/site-packages (from scikit-learn) (3.5.0)
# Using cached scikit_learn-1.5.2-cp311-cp311-macosx_12_0_arm64.whl (11.0 MB)
# Using cached imbalanced_learn-0.12.3-py3-none-any.whl (258 kB)
# Installing collected packages: scikit-learn, imbalanced-learn
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.1.3
#     Uninstalling scikit-learn-1.1.3:
#       Successfully uninstalled scikit-learn-1.1.3
#   Attempting uninstall: imbalanced-learn
#     Found existing installation: imbalanced-learn 0.9.1
#     Uninstalling imbalanced-learn-0.9.1:
#       Successfully uninstalled imbalanced-learn-0.9.1
# Successfully installed imbalanced-learn-0.12.3 scikit-learn-1.5.2
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install scikit-learn==1.1.3 imbalanced-learn==0.9.1
# Out:
# Collecting scikit-learn==1.1.3
#   Obtaining dependency information for scikit-learn==1.1.3 from https://files.pythonhosted.org/packages/91/54/14e64c540d554d29e40239850bc656e2d403870c6fb388319034eb878f0a/scikit_learn-1.1.3-cp311-cp311-macosx_12_0_arm64.whl.metadata
#   Using cached scikit_learn-1.1.3-cp311-cp311-macosx_12_0_arm64.whl.metadata (10 kB)
# Collecting imbalanced-learn==0.9.1
#   Obtaining dependency information for imbalanced-learn==0.9.1 from https://files.pythonhosted.org/packages/19/79/e86c8fd859dca4fb1fbfc61376afc63210177a235a7bfbe7219b02edf8f3/imbalanced_learn-0.9.1-py3-none-any.whl.metadata
#   Using cached imbalanced_learn-0.9.1-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: numpy>=1.17.3 in ./anaconda3/lib/python3.11/site-packages (from scikit-learn==1.1.3) (1.24.3)
# Requirement already satisfied: scipy>=1.3.2 in ./anaconda3/lib/python3.11/site-packages (from scikit-learn==1.1.3) (1.10.1)
# Requirement already satisfied: joblib>=1.0.0 in ./anaconda3/lib/python3.11/site-packages (from scikit-learn==1.1.3) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in ./anaconda3/lib/python3.11/site-packages (from scikit-learn==1.1.3) (3.5.0)
# Using cached scikit_learn-1.1.3-cp311-cp311-macosx_12_0_arm64.whl (7.6 MB)
# Using cached imbalanced_learn-0.9.1-py3-none-any.whl (199 kB)
# Installing collected packages: scikit-learn, imbalanced-learn
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.5.2
#     Uninstalling scikit-learn-1.5.2:
#       Successfully uninstalled scikit-learn-1.5.2
#   Attempting uninstall: imbalanced-learn
#     Found existing installation: imbalanced-learn 0.12.3
#     Uninstalling imbalanced-learn-0.12.3:
#       Successfully uninstalled imbalanced-learn-0.12.3
# Successfully installed imbalanced-learn-0.9.1 scikit-learn-1.1.3
# Note: you may need to restart the kernel to use updated packages.

# %%
from imblearn.over_sampling import SMOTE

# %%
x_res , y_res = SMOTE().fit_resample(x,y)

# %%
x_res.shape
# Out:
# (550380, 29)

# %%
y_res.shape
# Out:
# (550380,)

# %%
y_res.value_counts()
# Out:
# 0    275190
# 1    275190
# Name: Class, dtype: int64

# %%
x_train, x_test,y_train, y_test = train_test_split(x_res,y_res, test_size = 0.2, random_state = 42)

# %%
classifier = { 
"LogisticRegression":  LogisticRegression(),
"Decision Tree Classifier": DecisionTreeClassifier()}

for name, clf in classifier.items():
    print(f"\n----------{name}-----------")
    clf.fit(x_train,y_train)
    y_pred = clf.predict(x_test)
    print(f"\n Accuracy: {accuracy_score(y_pred,y_test)}")
    print(f"\n Precision: {precision_score(y_pred,y_test)}")
    print(f"\n Recall: {recall_score(y_pred,y_test)}")
    print(f"\n F1score: {f1_score(y_pred,y_test)}")
# Out:
# ----------LogisticRegression-----------
#
#  Accuracy: 0.9454467822231912
#
#  Precision: 0.9165136447102885
#
#  Recall: 0.9727346403210868
#
#  F1score: 0.9437876192348377
#
# ----------Decision Tree Classifier-----------
#
#  Accuracy: 0.9983011737345107
#
#  Precision: 0.998927331236478
#
#  Recall: 0.9976757699012202
#
#  F1score: 0.9983011583011584

# %%
dtclf = DecisionTreeClassifier()
dtclf.fit(x_res,y_res)
# Out:
# DecisionTreeClassifier()

# %%
import joblib

# %%
joblib.dump(dtclf,"credit_card_model.pkl")
# Out:
# ['credit_card_model.pkl']

# %%
model = joblib.load("credit_card_model.pkl")
